# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# time 
import time

# %matplotlib inline

# %% [markdown]
# Accelerometer signal at 200 Hz

# %%
df = pd.read_csv('Raw Data Video.csv', header=None)

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0  0.080423 -0.109908 -0.015433 -0.401333  0.416396
# 1  0.085468 -0.095908 -0.007837 -0.358775  0.371456
# 2  0.090513 -0.022601  0.007861 -0.307397  0.308327
# 3  0.095558  0.053802  0.011377 -0.284164  0.289436
# 4  0.100603  0.065152 -0.005276 -0.264284  0.272247

# %%
a = df[4].values
t = df[0].values

plt.plot(t,a)
plt.xlabel('Time (s)')
plt.ylabel('Absolute acceleration (m/s^2)')
plt.show()

# %%
# import FuncAnimation
from matplotlib import animation

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 47), ylim=(0,47))
line, = ax.plot([], [], lw=2)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Absolute acceleration (m/s^2)')

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    data = pd.read_csv('Raw Data Video.csv', header=None)
    y = data[4].values[:100*i]
    t = data[0].values[:100*i]
    line.set_data(t, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=93, interval=1, blit=True)

# save the animation as an gif
anim.save('acceleration.gif', fps=93./47.)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
# function that computes the standard deviation of every 200 data points
def std_deviation(data):
    std = []
    for i in range(0, len(data), 200):
        std.append(np.std(data[i:i+200]))
    return std

# %%
data = pd.read_csv('Raw Data Video.csv', header=None)
a = data[4].values
std = std_deviation(a)
time_values = range(0, len(std))

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 47), ylim=(0,12.5))
line, = ax.plot([], [], lw=2)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Standard deviation of acceleration (m/s^2)')


# animation function.  This is called sequentially
def animate(i):
    y = std[:i]
    t = time_values[:i]
    line.set_data(t, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=47, interval=1, blit=True)

# save the animation as an gif
anim.save('standard_deviation.gif', fps=1)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
a = df[4].values
std = std_deviation(a)
time_values = range(0, len(std))

plt.plot(time_values, std)
#plot hotizontal line at 1.0 
plt.axhline(y=0.75, color='r', linestyle='-')

# %%
# Using readlines()
file1 = open('Raw Data Video.csv', 'r')
Lines = file1.readlines()

time_values = []
state_values = []
acc = []

  
count = 0
state = 0 

# Strips the newline character
for line in Lines:
    # rest for 0.1 seconds
    time.sleep(0.0039)

    count += 1
    
    time_values.append(float(line.split(',')[0]))
    acc.append(float(line.split(',')[4]))

    if count%200 == 0:
        
        # compute standard deviation of last 200 data points
        std = np.std(acc[-200:])

        if std < 0.75 and (state == 1 or state == 2):
            state = 0
            print('User at rest. State ', 0)
        
        elif std > 0.75 and (std < 10 and state == 0 or state == 2):
            state = 1
            print('User walking. State ', 1)
        
        elif std > 10 and (state == 1 or state == 0):
            state = 2

            print('')
            print('Fall detected at time: ', np.round(time_values[-1],2))
            print('Standard deviation: ', np.round(std,2))
            print('')

            # ask user if the person has fallen through a printed message
            ans = input('Do you need asistance? (y/n): ')
            if ans == 'n':
                print('Thank God!')
                print('')
            
            else:
                print('Calling 911...')
                print('')

        state_values.append(state)
# Out:
# User walking. State  1
# User at rest. State  0
# User walking. State  1
#
# Fall detected at time:  40.44
# Standard deviation:  10.1
#
# Thank God!
#
# User walking. State  1
# User at rest. State  0

# %%
# plot state values
plt.plot(np.arange(len(state_values)),state_values)

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

# intialize two line objects (one in each axes)
line1, = ax1.plot([], [], lw=2)
line2, = ax2.plot([], [], lw=2, color='r')
line = [line1, line2]

# initialization function: plot the background of each frame
def init():
    line[0].set_data([], [])
    line[1].set_data([], [])
    return line

ax1.set_ylim(0, 12.5)
ax1.set_xlim(0, 47)
ax1.set_ylabel('Standard deviation')
ax1.grid()

ax2.set_ylim(0, 3)
ax2.set_xlim(0, 47)
ax2.set_ylabel('State')
ax2.set_xlabel('Time (s)')
ax2.set_yticks([0, 1, 2])
ax2.set_yticklabels(['Rest', 'Walking', 'Fall'])
ax2.grid()

# animation function.  This is called sequentially
def animate(i):
    y = std[:i]
    t = time_values[:i]
    line[0].set_data(t, y)

    y2 = state_values[:i]
    line[1].set_data(t, y2)

    return line

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=47, interval=1, blit=True)

# save the animation as an gif
anim.save('state.gif', fps=1)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
